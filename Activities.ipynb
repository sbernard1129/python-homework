# %%
print(f"Hello World")
# Out:
# Hello World

# %%
# Percent Increase Bonus Activity

precision = 2

# Create float variable for original_price
original_price = 198.87

# Create float variable for current_price
current_price = 254.32

# Calculate difference between current_price and original_price
increase = current_price - original_price

# Calculate percent_increase
percent_increase = (increase / original_price) * 100

# Print original_price
print(f"Apple's original stock price was ${original_price}")

# Print current_price
print(f"Apples current stock price is ${current_price}")

# Print percent_increase
print(f"Apple's percent increase price is {percent_increase:.{precision}f}%")
# Out:
# Apple's original stock price was $198.87
# Apples current stock price is $254.32
# Apple's percent increase price is 27.88%

# %%
# 1.
x = 5
y = 10
if 2 * x > 10:
    print("Question 1 works!")
else:
    print("Oooo needs some work")

# 2.
x = 5
y = 10
if len("Dog") < x:
    print("Question 2 works!")
else:
    print("Still missing out")

# 3.
age = 21
if age > 20:
    print("You are of drinking age!")
else:
    print("Argggggh! You think you can hoodwink me, matey?! You're too young to drink!")

# 4.
x = 2
y = 5
if (x ** 3 >= y) and (y ** 2 < 26):
    print("GOT QUESTION 4!")
else:
    print("Oh good you can count")

# 5.
height = 66
age = 16
adult_permission = True

if (height > 70) and (age >= 18):
    print("Can ride all the roller coasters")
elif (height > 65) and (age >= 18):
    print("Can ride moderate roller coasters")
elif (height > 60) and (age >= 18):
    print("Can ride light roller coasters")
elif ((height > 50) and (age >= 18)) or ((adult_permission) and (height > 50)):
    print("Can ride bumper cars")
else:
    print("Stick to lazy river")
# Out:
# Oooo needs some work
# Question 2 works!
# You are of drinking age!
# GOT QUESTION 4!
# Can ride bumper cars

# %%
# Create a variable named cheer and give it a word to cheer (i.e. Python or FinTech)
cheer = "Python"

# Below strings can be used to add fun
cheer_symbol = "*\O/*"
cheer_symbol_2 = "ヘ( ^o^)ノ＼(^_^ )"

# Loop through string and print each letter with a cheer
for x in cheer:
    print(f"Give me a {x}! \n{x}!")

# Print excitement to screen
print("\nWhat does that spell?!")
print(cheer + "!\nWoohoo! Go " + cheer + "!")
print(cheer_symbol * 3)
print(cheer_symbol_2)
# Out:
# Give me a P!
# P!
# Give me a y!
# y!
# Give me a t!
# t!
# Give me a h!
# h!
# Give me a o!
# o!
# Give me a n!
# n!
#
# What does that spell?!
# Python!
# Woohoo! Go Python!
# *\O/**\O/**\O/*
# ヘ( ^o^)ノ＼(^_^ )

# %%
balance = 10000

original_price = 360.35
current_price = 293.33
increase = current_price - original_price
percent_increase = (increase / original_price) * 100

# Thresholds in percent
threshold_to_purchase = -20.0
threshold_to_sell = 20.0

if(percent_increase <= threshold_to_purchase) and (current_price * 5 < balance):
    recommendation = "buy"
    
elif(percent_increase >= threshold_to_sell):
    recommendation = "sell"
    
else:
    recommendation = "hold"
    
print(f"Netflix stock recommendation: {recommendation}")
# Out:
# Netflix stock recommendation: hold

# %%
original_price = 360.35
current_price = 293.33
increase = current_price - original_price
percent_increase = (increase / original_price) * 100

print(f"{percent_increase}")

# Thresholds in percent
threshold_to_purchase = -20.0
threshold_to_sell = 20.0

if(percent_increase <= threshold_to_purchase):
    recommendation = "buy"
    
elif(percent_increase >= threshold_to_sell):
    recommendation = "sell"
    
else:
    recommendation = "hold"
    
print(f"Netflix stock recommendation: {recommendation}")
# Out:
# -18.598584709310405
# Netflix stock recommendation: hold

# %%
# @TODO: Create a list of groceries
grocery_list = ["Water", "Butter", "Eggs", "Apples", "Cinnamon", "Sugar", "Milk"]

# @TODO: Find the first two items on the list
print(f"Printing first 2 items:")
for x in range(2):
    print(f"{x + 1}. {grocery_list[x]}")

# @TODO: Find the last five items on the list
print(f"Printing last 5 items:")
y = len(grocery_list)
for x in range(-5, 0):
    print(f"{x + y + 1}. {grocery_list[x]}")

# @TODO: Find every other item on the list, starting from the second item
print(f"Printing every other item, starting from second item")
for x in range(1, len(grocery_list), 2):
    print(f"{x + 1}. {grocery_list[x]}")

# @TODO: Add an element to the end of the list
print(f"Adding element to end of list")
grocery_list.append("Flour")
print(f"Printing new list")
for x in range(len(grocery_list)):
    print(f"{x + 1}. {grocery_list[x]}")

# @TODO: Changes a specified element within the list at the given index
print(f"Updating 'Apples' to 'Gala Apples'")
z = grocery_list.index("Apples")
grocery_list[z] = "Gala Apples"

# @TODO: Calculate how many items you have in the list
print(f"Total number of items: {len(grocery_list)}")
# Out:
# Printing first 2 items:
# 1. Water
# 2. Butter
# Printing last 5 items:
# 3. Eggs
# 4. Apples
# 5. Cinnamon
# 6. Sugar
# 7. Milk
# Printing every other item, starting from second item
# 2. Butter
# 4. Apples
# 6. Sugar
# Adding element to end of list
# Printing new list
# 1. Water
# 2. Butter
# 3. Eggs
# 4. Apples
# 5. Cinnamon
# 6. Sugar
# 7. Milk
# 8. Flour
# Updating 'Apples' to 'Gala Apples'
# Total number of items: 8

# %%
# -*- coding: utf-8 -*-
"""
Student Do: Trading Log.

This script demonstrates how to perform basic analysis of trading profits/losses
over the course of a month (20 business days).
"""

# @TODO: Initialize the metric variables
count = 0
total = 0
average = 0
profitable_count = 0
unprofitable_count = 0


# @TODO: Initialize lists to hold profitable and unprofitable day profits/losses
gain_loss = []
profitable_list = []
unprofitable_list = []


# List of trading profits/losses
trading_pnl = [ -224,  352, 252, 354, -544,
                -650,   56, 123, -43,  254,
                 325, -123,  47, 321,  123,
                 133, -151, 613, 232, -311 ]

minimum = trading_pnl[0]
maximum = trading_pnl[0]

# @TODO: Iterate over each element of the list
for tip in trading_pnl:

    # @TODO: Cumulatively sum up the total and count
    count = count + 1
    total = total + tip

    # @TODO: Write logic to determine minimum and maximum values
    if(tip < minimum):
        minimum = tip
        
    if(tip > maximum):
        maximum = tip

    # @TODO: Write logic to determine profitable vs. unprofitable days
    if(tip <= 0):
        gain_loss.append("unprofitable")
        unprofitable_list.append(tip)
        unprofitable_count = unprofitable_count + 1
    else:
        gain_loss.append("profitable")
        profitable_list.append(tip)
        profitable_count = profitable_count + 1

# @TODO: Calculate the average
average = total / count

# @TODO: Print out the summary statistics
print(f"---------Summary Statistics----------")
print(f"Number of Total Days: {count}")
print(f"Number of Profitable Days: {profitable_count}")
print(f"Number of Unprofitable Days: {unprofitable_count}")
print(f"Percentage of Profitable Days: {((profitable_count / count) * 100):.2f}%")
print(f"Percentage of Profitable Days: {((unprofitable_count / count) * 100):.2f}%")
print(f"-------------------------------------")
print(f"Profitable Days: {profitable_list}")
print(f"Unprofitable Days: {unprofitable_list}")
print(f"-------------------------------------")
print(f"Total Profits/Losses: {total:.2f}")
print(f"Daily Average: {average:.2f}")
print(f"Worst Loss: {minimum:.2f}")
print(f"Best Gain: {maximum:.2f}")
# Out:
# ---------Summary Statistics----------
# Number of Total Days: 20
# Number of Profitable Days: 13
# Number of Unprofitable Days: 7
# Percentage of Profitable Days: 65.00%
# Percentage of Profitable Days: 35.00%
# -------------------------------------
# Profitable Days: [352, 252, 354, 56, 123, 254, 325, 47, 321, 123, 133, 613, 232]
# Unprofitable Days: [-224, -544, -650, -43, -123, -151, -311]
# -------------------------------------
# Total Profits/Losses: 1139.00
# Daily Average: 56.95
# Worst Loss: -650.00
# Best Gain: 613.00

# %%
# -*- coding: utf-8 -*-
"""
Student Activity: Market Capitalization.

This script showcases the use of Python Dicts to determine the
bank names associated with the corresponding market cap ranges.
"""

# @TODO: Initialize a dictionary of banks and market caps (in billions)
banks = {
    "JP Morgan Chase": 327,
    "Bank of America": 302,
    "Citigroup": 173,
    "Wells Fargo": 273,
    "Goldman Sachs": 87,
    "Morgan Stanley": 72,
    "U.S. Bancorp": 83,
    "TD Bank": 108,
    "PNC Financial Services": 67,
    "Capital One": 47,
    "FNB Corporation": 4,
    "First Hawaiian Bank": 3,
    "Ally Financial": 12,
    "Wachovia": 145,
    "Republic Bancorp": .97
}

total_market_cap = 0
average = 0
minimum_key = ""
minimum_value = 0
maximum_key = ""
maximum_value = 0

# @TODO: Change the market cap for 'Citigroup'
banks["Citigroup"] = 170

# @TODO: Add a new bank and market cap pair
banks["American Express"] = 33

# @TODO: Remove a bank from the dictionary
del banks["Wachovia"]

# Mega Cap: Firms with a market capitalization over $300 billion.
# Large Cap: Firms with a market capitalization over 10 billion. ...
# Mid Cap: A market capitalization between $2 and $10 billion.
# Small Cap: A market capitalization between $300 million and $2 billion.

# @TODO: Initialize market cap lists
mega_cap = []
large_cap = []
mid_cap = []
small_cap = []

for bank in banks:

    # @TODO: Calculate sum of market caps and number of banks in the dictionary



    # @TODO: Logic to determine min value and associated key
    if(banks[bank] < minimum_value):
        minimum_key = bank
        minimum_value = banks[bank]
        
    if(banks[bank] > maximum_value):
        maximum_key = bank
        maximum_value = banks[bank]

    # @TODO: Group banks by categories of market caps










# @TODO: Calculate average market cap of banks in the dictionary


# @TODO: Print the metrics
# Out:
# JP Morgan Chase
# Bank of America
# Citigroup
# Wells Fargo
# Goldman Sachs
# Morgan Stanley
# U.S. Bancorp
# TD Bank
# PNC Financial Services
# Capital One
# FNB Corporation
# First Hawaiian Bank
# Ally Financial
# Republic Bancorp
# American Express

# %%
# -*- coding: utf-8 -*-
"""
Student Activity: Weekly Gains.

This script showcases how to use nested list/dict objects to
calculate weekly gains of stock tickers.
"""

# Dictionary of List of Lists
# Key: Stock Ticker | Value: List of Records
# Record: Date, Open, High, Low, Close
historical_stock_data = {
    "AAPL": [
        ["04-17-2019", 199.54, 203.38, 198.61, 203.13],
        ["04-18-2019", 199.46, 201.37, 198.56, 199.25],
        ["04-19-2019", 198.58, 199.85, 198.01, 199.23],
        ["04-20-2019", 199.20, 200.14, 196.21, 198.87],

    ],
    "MU": [
        ["04-17-2019", 43.20, 43.53, 42.79, 43.40],
        ["04-18-2019", 43.36, 44.05, 42.76, 43.15],
        ["04-19-2019", 42.26, 42.93, 42.08, 42.76],
        ["04-20-2019", 42.17, 42.23, 41.20, 41.82],

    ],
    "AMD": [
        ["04-17-2019", 27.60, 27.88, 27.34, 27.68],
        ["04-18-2019", 28.21, 28.27, 27.22, 27.49],
        ["04-19-2019", 27.72, 28.18, 27.49, 27.93],
        ["04-20-2019", 27.80, 27.84, 26.96, 27.33],

    ],
    "TWTR": [
        ["04-17-2019", 34.67, 34.86, 34.32, 34.40],
        ["04-18-2019", 34.73, 34.90, 34.20, 34.48],
        ["04-19-2019", 34.84, 34.99, 34.23, 34.46],
        ["04-20-2019", 34.38, 35.03, 34.34, 34.71],

    ]
}

# Dictionary of Dictionary
# Key: Stock Ticker | Value: Dictionary
new_records = {
    "AAPL": {
        "date": "04-21-2019",
        "open": 200.85,
        "high": 201.00,
        "low": 198.44,
        "close": 198.95
    },
    "MU": {
        "date": "04-21-2019",
        "open": 42.85,
        "high": 43.20,
        "low": 41.81,
        "close": 42.01
    },
    "AMD": {
        "date": "04-21-2019",
        "open": 28.21,
        "high": 28.38,
        "low": 27.66,
        "close": 27.85
    },
    "TWTR": {
        "date": "04-21-2019",
        "open": 34.67,
        "high": 34.83,
        "low": 34.11,
        "close": 34.37
    }
}

# @TODO: Set each ticker's new record: date, open, high, low, close
keys = list(new_records.keys())

# for key in keys:
    # list_new_record_values = list(new_records[key].values())
    # historical_stock_data[key].append(list_new_record_values)
    
# print(historical_stock_data)

for new_dict in new_records:
    # historical_stock_data[new_dict].append(["04-17-2020", 199.54, 203.38, 198.61, 203.13])
    # print(new_records[new_dict])
    # print(historical_stock_data[new_dict][4])
    # print(historical_stock_data[new_dict])
    # print(new_dict["date"])
    # print(historical_stock_data[new_dict])
    new_list = [new_records[new_dict]["date"], new_records[new_dict]["open"], new_records[new_dict]["high"], new_records[new_dict]["low"], new_records[new_dict]["close"]]
    historical_stock_data[new_dict].append(new_list)
    # print("loop complete")

print("Apple")
print(historical_stock_data["AAPL"])
print("Micron")
print(historical_stock_data["MU"])
print("AMD")
print(historical_stock_data["AMD"])
print("Twitter")
print(historical_stock_data["TWTR"])

# @TODO: Choice 1: Add a new round of entries to the 'historical_stock_data' dictionary






# @TODO: Choice 2: Add a new round of entries via for loop to the 'historical_stock_data' dictionary






# @TODO: Print out the modified 'historical_stock_data' dictionary
# Out:
# Apple
# [['04-17-2019', 199.54, 203.38, 198.61, 203.13], ['04-18-2019', 199.46, 201.37, 198.56, 199.25], ['04-19-2019', 198.58, 199.85, 198.01, 199.23], ['04-20-2019', 199.2, 200.14, 196.21, 198.87], ['04-21-2019', 200.85, 201.0, 198.44, 198.95]]
# Micron
# [['04-17-2019', 43.2, 43.53, 42.79, 43.4], ['04-18-2019', 43.36, 44.05, 42.76, 43.15], ['04-19-2019', 42.26, 42.93, 42.08, 42.76], ['04-20-2019', 42.17, 42.23, 41.2, 41.82], ['04-21-2019', 42.85, 43.2, 41.81, 42.01]]
# AMD
# [['04-17-2019', 27.6, 27.88, 27.34, 27.68], ['04-18-2019', 28.21, 28.27, 27.22, 27.49], ['04-19-2019', 27.72, 28.18, 27.49, 27.93], ['04-20-2019', 27.8, 27.84, 26.96, 27.33], ['04-21-2019', 28.21, 28.38, 27.66, 27.85]]
# Twitter
# [['04-17-2019', 34.67, 34.86, 34.32, 34.4], ['04-18-2019', 34.73, 34.9, 34.2, 34.48], ['04-19-2019', 34.84, 34.99, 34.23, 34.46], ['04-20-2019', 34.38, 35.03, 34.34, 34.71], ['04-21-2019', 34.67, 34.83, 34.11, 34.37]]

# %%
""""
Determine the Compound Annual Growth Rate for an investment
"""

# Declare a variable beginning_balance as a float
beginning_balance = 29000.00

# Declare a variable ending_balance as float
ending_balance = 45000.00

# Declare a variable years as an float
years = 1.0

# Define a function called calculate_compound_growth_rate with three arguments: beginning_balance, ending_balance, years. Function should output growth_rate.
def calculate_compound_growth_rate(beginning_balance, ending_balance, years):
    result = ((ending_balance / beginning_balance)**(1 / years)) - 1
    return result

# Call calculate_compound_growth_rate using beginning_balance, ending_balance, and years. Capture as year_one_growth.
year_one_growth = calculate_compound_growth_rate(beginning_balance, ending_balance, 1)

# Update beginning_balance and ending balance for year two, and then execute calculate_compound_growth_rate
beginning_balance = ending_balance
ending_balance = 47000.00

# Call calculate_compound_growth_rate using beginning_balance, ending_balance, and years. Capture as year_two_growth.
year_two_growth = calculate_compound_growth_rate(beginning_balance, ending_balance, 1)

# Update beginning_balance and ending balance for year three, and then execute calculate_compound_growth_rate
beginning_balance = ending_balance
ending_balance = 48930.00

# Call calculate_compound_growth_rate using beginning_balance, ending_balance, and years. Capture as year_three_growth.
year_three_growth = calculate_compound_growth_rate(beginning_balance, ending_balance, 1)

# Use Python round() function to round year_one_growth, year_two_growth, and year_three_growth. Capture these as new variables.
rounded_year_one_growth = round(year_one_growth, 2)
rounded_year_two_growth = round(year_two_growth, 2)
rounded_year_three_growth = round(year_three_growth, 2)

# Print year_one_growth, year_two_growth, year_three_growth as percents using string formatting
print(f"Year One Growth: {rounded_year_one_growth:.2f}")
print(f"Year Two Growth: {rounded_year_two_growth:.2f}")
print(f"Year Three Growth: {rounded_year_three_growth:.2f}")


# Challenge

# Create a global, empty list


# Define a function called
# Out:
# Year One Growth: 0.55
# Year Two Growth: 0.04
# Year Three Growth: 0.04

# %%
# -*- coding: utf-8 -*-
"""Refresher activity.

This script will use variables, conditionals, lists, dicts, and functions
to print out different greetings for customers based on their
business tier (determined by revenue).
"""

# List of dicts
customers = [
    { "first_name": "Tom", "last_name": "Bell", "revenue": 0 },
    { "first_name": "Maggie", "last_name": "Johnson", "revenue": 1032 },
    { "first_name": "John", "last_name": "Spectre", "revenue": 2543 },
    { "first_name": "Susy", "last_name": "Simmons", "revenue": 5322 }
]

# @TODO Define a function that accepts a customer first_name, last_name, and
# revenue and returns a custom greeting with the full name.
# Use these ranges to determine the business tier (and corresponding message)
# for each customer.
#   Platinum = 3001+
#   Gold = 2001-3000
#   Silver = 1001-2000
#   Bronze = 0-1000
def create_greeting(first_name, last_name, revenue):
    tier_low_threshold = { "Bronze": 0, "Silver": 1000, "Gold": 2000, "Platinum": 3000}
    tier = "Bronze"
    for key in tier_low_threshold.keys():
        if (revenue > tier_low_threshold[key]):
            tier = key
    greeting = "Hello " + first_name + " " + last_name + ", your business tier is " + tier
    return greeting

# @TODO: Loop through the list of customers and use your function to print
for customer in customers:
    print(create_greeting(customer["first_name"], customer["last_name"], customer["revenue"]))
# custom greetings for each customer.
# @TODO: YOUR CODE HERE!
# Out:
# Hello Tom Bell, your business tier is Bronze
# Hello Maggie Johnson, your business tier is Silver
# Hello John Spectre, your business tier is Gold
# Hello Susy Simmons, your business tier is Platinum

# %%
# -*- coding: utf-8 -*-
"""
Zero-Coupon Bond Valuation.

This script will calculate the present value of zero-coupon bonds, compare the present value to the price of the bond, and determine the corresponding action (buy, not buy, neutral).
"""

# @TODO: Create a function to calculate present value
def calculate_present_value(future_value, discount_rate, years, compounding_periods = 1):
    result = future_value / ((1 + (discount_rate / compounding_periods))**(compounding_periods * years))
    return result

# Intialize the zero-coupon bond parameters, assume compounding period is equal to 1
price = 700
future_value = 1000
discount_rate = .1
compounding_periods = 1
years = 5

# @TODO: Call the calculate_present_value() function and assign to a variables
present_value = calculate_present_value(future_value, discount_rate, years)

# @TODO: Determine if the bond is worth it
print(f"Price: {price}")
print(f"Future value: {future_value}")
print(f"Calculated present value: {present_value}")
if(present_value <= price):
    print(f"Don't buy")
else:
    print(f"Buy")
# Out:
# Price: 700
# Future value: 1000
# Calculated present value: 620.9213230591549
# Don't buy

# %%
# -*- coding: utf-8 -*-
"""Student Activity: Financial Analysis using NPV.

This script will choose the optimal project scenario to
undertake based on max NPV values.
"""

# @TODO: Import the NumPy Financial (numpy_financial) library
import numpy as np
import numpy_financial as npf

# Discount Rate
discount_rate = .1

# Initial Investment, Cash Flow 1, Cash Flow 2, Cash Flow 3, Cash Flow 4
cash_flows_conservative = [-1000, 400, 400, 400, 400]
cash_flows_neutral = [-1500, 600, 600, 600, 600]
cash_flows_aggressive = [-2250, 800, 800, 800, 800]

max_npv = 0
max_npv_key = ""

npv_dict = {}
cf_dict = {"conservative": cash_flows_conservative, "neutral": cash_flows_neutral, "aggressive": cash_flows_aggressive}

# @TODO: Calculate the NPV for each scenario
for key in cf_dict.keys():
    npv_dict[key] = npf.npv(discount_rate, cf_dict[key])
    if(npv_dict[key] > max_npv):
        max_npv = npv_dict[key]
        max_npv_key = key
        

npv_dict['max'] = max_npv

print(f"Max strategy: {max_npv_key}")
print(f"Max NPV: {max_npv:.2f}")
# Out:
# Max strategy: neutral
# Max NPV: 401.92

# %%
from pathlib import Path

absolute_filepath = Path(r'C:\Users\mathl\Jupyter-Workspace\week_2_activities\untitled.txt')
with open(absolute_filepath, 'r') as file:
    for line in file:
        print(line.split(", "))

# %%
# -*- coding: utf-8 -*-
"""Student Do: E-Commerce Traffic.

This script will parse through a text file and sum the total
number of customers and the count of days in the text file to
calculate the daily average of customer traffic for an e-commerce
business.
"""

# @TODO: From the pathlib library, import the main class Path
from pathlib import Path

# @TODO: Check the current directory where the Python program is executing from
cwd = Path.cwd()
print(f"Current Working Directory: {cwd}\n")

# @TODO: Set the path using Pathlib
relative_filepath = Path(r'customer_traffic.txt')

# Initialize variables
customer_total = 0
day_count = 0

# @TODO: Open the file in "read" mode ('r') and store the contents in the variable 'file'
with open(relative_filepath, 'r') as file:

    for line in file:
        customer_total += int(line.strip())
        day_count += 1

# @TODO: Print out customer_total and day_count
print(f"Total Customers: {customer_total}")
print(f"Total Days: {day_count}")

daily_average = customer_total / day_count
print(f"Daily Average: {daily_average:.2f}")

# @TODO: Set output file name
relative_filepath = Path(r'output.txt')

# @TODO: Open the output path as a file object
with open(relative_filepath, 'w') as file:
    file.write("Daily average: " + str(daily_average))
# Out:
# Current Working Directory: C:\Users\mathl\Jupyter-Workspace\week_2_activities
#
# Total Customers: 4945
# Total Days: 100
# Daily Average: 49.45

# %%
# -*- coding: utf-8 -*-
"""Student Do: Sales Analysis.

This script will use the Pathlib library to set the file path,
use the csv library to read in the file, and iterate over each
row of the file to calculate customer sales averages.
"""

# @TODO: Import the pathlib and csv library
from pathlib import Path
import csv

# @TODO: Set the file path
relative_filepath = Path(r'resources_sales.csv')

# Initialize list of records
records = []
line_num = 0

# @TODO: Open the csv file as an object
with open(relative_filepath, 'r') as csvfile:
    
    csvreader = csv.reader(csvfile, delimiter=',')

    # @TODO:
    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object

    header = next(csvreader)
    line_num += 1
    print(f"{header} <---- HEADER")
    
    header.append('Average')

    print(f"{header} <---- HEADER")
    
    records.append(header)

    for row in csvreader:

        # @TODO:
        # Set the 'name', 'count', 'revenue' variables for better
        name = str(row[0])
        count = int(row[1])
        revenue = float(row[2])
        # readability, convert strings to ints for numerical calculations
        average = round(revenue / count, 2)

        # @TODO: Append the average to the row
        row.append(average)

        # @TODO: Append the row to the list of records
        records.append(row)

# @TODO: Set the path for the output.csv
relative_filepath = Path(r'resources_sales_average.csv')

with open(relative_filepath, 'w') as csvfile:

    csvwriter = csv.writer(csvfile, delimiter=',')
    
    for record in records:
        csvwriter.writerow(record)
# Out:
# ['Name', 'Count', 'Revenue'] <---- HEADER
# ['Name', 'Count', 'Revenue', 'Average'] <---- HEADER
